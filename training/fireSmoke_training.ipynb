# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 31.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import torch

def main():
    # -------------------------------
    # Configuration
    # -------------------------------
    MODEL_NAME = "yolov8n.pt"   # best for small datasets
    DATA_YAML = r"/content/drive/MyDrive/Fire_Smoke_model/dataset/data.yaml"
    EPOCHS = 300
    IMG_SIZE = 640
    BATCH_SIZE = 8
    DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

    # -------------------------------
    # Load pretrained YOLOv8 model
    # -------------------------------
    model = YOLO(MODEL_NAME)

    # -------------------------------
    # Train the model
    # -------------------------------
    model.train(
        data=DATA_YAML,
        epochs=EPOCHS,
        imgsz=IMG_SIZE,
        batch=BATCH_SIZE,
        device=DEVICE,
        optimizer="AdamW",     # stable for small datasets
        lr0=1e-3,
        patience=30,           # early stopping
        pretrained=True,
        augment=True,
        project= "/content/drive/MyDrive/Fire_Smoke_model/runs",
        name="yolov8n_fire_smoke",
        exist_ok=True
    )

    print("✅ Training completed successfully.")

if __name__ == "__main__":
    main()
# Out:
# Ultralytics 8.3.248 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO
import os

def main():
    # -------------------------------
    # Paths
    # -------------------------------
    MODEL_PATH = "/content/drive/MyDrive/Fire_Smoke_model/runs/yolov8n_fire_smoke/weights/best.pt"
    VIDEOS_FOLDER = "/content/drive/MyDrive/Fire_Smoke_model/Test data/videos"   # folder jisme images hain
    CONF_THRESHOLD = 0.25

    # -------------------------------
    # Load trained model
    # -------------------------------
    model = YOLO(MODEL_PATH)

    # -------------------------------
    # Run inference on image folder
    # -------------------------------
    results = model(
        source=VIDEOS_FOLDER,
        conf=CONF_THRESHOLD,
        save=True,
        project="/content/drive/MyDrive/Fire_Smoke_model/Test data",  # parent folder
        name="predicted_videos",  # folder jisme results directly save hon
        exist_ok=True
    )

    print("✅ Inference completed successfully.")
    print("📂 Results saved in: /content/drive/MyDrive/Fire_Smoke_model/Test data/predicted_images")

if __name__ == "__main__":
    main()
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/2 (frame 1/83) /content/drive/MyDrive/Fire_Smoke_model/Test data/videos/WhatsApp Video 2026-01-04 at 8.45.08 PM.mp4: 640x384 (no detections), 41.0ms
# video 1/2 (frame 2/83) /content/drive/MyDrive/Fire_Smoke_model/Test data/videos/WhatsApp Video 2026-01-04 at 8.45.08 PM.mp4: 640x384 1 fire_smoke, 6.3ms
# ...
